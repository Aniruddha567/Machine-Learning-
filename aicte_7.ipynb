# %% [markdown]
# # Object detection

# %% [markdown]
# ## Import dependecies

# %%
from ultralytics import YOLO
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# ## Train the model

# %%
model = YOLO("yolov5su.pt")
model.train(data="P:/Python/aicte AI_ML/soccer_ball/data.yaml", epochs=3, imgsz=416, batch=2, device='cpu')
# Out:
# Ultralytics 8.3.147  Python-3.10.15 torch-2.7.0+cu118 CPU (Intel Core(TM) i3-1005G1 1.20GHz)
# ...

# %% [markdown]
# ## Training results

# %%
from IPython.display import Image
Image(filename='runs/detect/train9/results.png')

# %% [markdown]
# ## Test the model

# %%
# !yolo task=detect mode=predict model=runs/detect/train9/weights/best.pt source= 'football.webp' conf=0.25 save=True show=True save_txt=True imgsz=416 device='cpu'
# Out:
# WARNING Environment does not support cv2.imshow() or PIL Image.show()
# OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1301: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'
#
# Ultralytics 8.3.147  Python-3.10.15 torch-2.7.0+cu118 CPU (Intel Core(TM) i3-1005G1 1.20GHz)
# YOLOv5s summary (fused): 84 layers, 9,111,923 parameters, 0 gradients, 23.8 GFLOPs
#
# image 1/1 p:\Python\aicte AI_ML\football.webp: 256x416 1 soccer ball, 140.3ms
# Speed: 13.1ms preprocess, 140.3ms inference, 33.4ms postprocess per image at shape (1, 3, 256, 416)
# Results saved to runs\detect\predict
# 1 label saved to runs\detect\predict\labels
#  Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image, display
display(Image(filename='runs/detect/predict/football.jpg'))
